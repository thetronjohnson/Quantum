# %%
import qiskit
from qiskit import IBMQ
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-1cee3ef04336> in <module>
#       1 import qiskit
# ----> 2 from qiskit import IBMQ
#
# ImportError: cannot import name 'IBMQ'

# %%
IBMQ.save_account('2afc5b225f65797a6643db060d6a2b44e93541d355b3c55274965072cab8b7cd5c5526666d206fa89ea1004859c2505ce6526ec0cf8a977148ba6964758dc25f')

# %%
IBMQ.load_account()
# Out:
# ---------------------------------------------------------------------------
# IBMQAccountError                          Traceback (most recent call last)
# <ipython-input-13-beb09c0bf764> in <module>
# ----> 1 IBMQ.load_account()
#
# ~/anaconda3/envs/quantum/lib/python3.6/site-packages/qiskit/providers/ibmq/ibmqfactory.py in load_account(self)
#     170         if not version_info['new_api']:
#     171             raise IBMQAccountError('IBM Q Experience v1 credentials found. ' +
# --> 172                                    UPDATE_ACCOUNT_TEXT)
#     173
#     174         if 'api-auth' not in version_info:
#
# IBMQAccountError: 'IBM Q Experience v1 credentials found. Please update your accounts and programs by following the instructions here:\nhttps://github.com/Qiskit/qiskit-ibmq-provider#updating-to-the-new-ibm-q-experience'
